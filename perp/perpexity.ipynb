# %% [markdown]
# # perplexity

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
perps=pd.DataFrame()
cohr=pd.DataFrame()
for i in range(2017,2023+1):
    df=pd.read_csv("perp/perp_cvpr%d.csv"%i)
    perps[str(i)]=df["perplexity"]
    cohr[str(i)]=df["coherence"]

#perp_cvpr2017["perplexity"].plot()
perps
# Out:
#        2017     2018     2019     2020     2021     2022     2023
# 0   132.732  135.246  147.135  157.161  154.530  160.061  165.656
# 1   127.769  131.751  141.028  153.489  151.311  155.948  160.480
# 2   125.253  127.219  137.763  150.068  147.460  152.098  157.054
# 3   125.529  125.061  136.565  147.358  142.982  146.703  152.785
# 4   121.787  122.973  134.251  145.320  139.825  144.181  150.904
# 5   117.441  120.561  130.208  140.696  137.100  144.168  146.443
# 6   117.611  119.542  128.688  140.965  135.393  139.726  144.900
# 7   118.170  118.601  126.748  139.931  132.882  138.840  144.094
# 8   115.359  117.586  127.584  138.132  133.107  137.113  141.699
# 9   114.853  116.651  125.737  135.157  131.614  137.263  140.002
# 10  115.364  113.915  120.890  136.207  127.448  133.688  137.617
# 11  112.784  114.179  123.794  135.410  128.789  132.735  135.559

# %%
perps.plot(marker="o", figsize=(20,10),)
# Out:
# <AxesSubplot:>

# %%
cohr.plot(marker="o", figsize=(20,10),)
# Out:
# <AxesSubplot:>
